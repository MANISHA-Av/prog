# %% [markdown]
# # Data

# %%
import numpy as np
x=np.arange(0,100)
y = x*2
z = x**2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Exercise 1

# %%
fig=plt.figure()
ax=fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %% [markdown]
# ## Exercise 2

# %%
fig=plt.figure()
axes1=fig.add_axes([0,0,1,1])
axes2=fig.add_axes([0.2,0.5,.2,.2])

# %%
fig=plt.figure()
axes1=fig.add_axes([0,0,1,1])
axes2=fig.add_axes([0.2,0.5,.2,.2])

axes1.plot(x,y)
axes2.plot(x,y)

# %% [markdown]
# ## Exercise 4

# %%
plt.subplots(nrows=1,ncols=2)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x06A1A130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00DF9430>],
#        dtype=object))

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,figsize=(8,2))
axes[0].plot(x,y,color='purple',lw=3)
axes[1].plot(x,z,color='red',ls='--')
